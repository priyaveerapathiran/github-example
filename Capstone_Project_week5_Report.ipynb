# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# # Introduction:

# %% [markdown]
# ## Background:

# %% [markdown]
#               New York is considered as financial capital of America and it is also a best place for small businesses those runs shop in Main Streets. It has five boroughs namely, Manhattan, Queens, Brooklyn, Bronx, Staten Island. New York is a best know for its tourist attractions for people of all age group like historical monuments, parks, museums, zoo etc. It is a multicultural city with wide variety of Ethnic group of people. Places like Little China, Little India lots of restaurants with variety of cuisines are evidence for its multiculturality.
#               There are many small scale business run by people in New York like jewellery, saloons, brewery, florist shops, and restaurants, which is considered as the most common business. Some restaurants serve different cuisines in one roof which is a multicuisine restaurant or with specific type of cuisine. One can see number of restaurants with variety of cuisines in every street of  New York. Some are,
#                          Scalini Fedeli ---          Italian Restaurant
#                          Wu Hop                       Chinese Restaurant
#                          Blue Hill                       American Restaurant
#                          Tamarind Tribeca      Indian Restaurant
#                          Pongsri                        Thai Restaurant
#                          Toloache                      2Mexican Restaurant
#                          Taci’s Beity                  Multicuisine Restaurant

# %% [markdown]
# ## Problem:

# %% [markdown]
#            A businessman wants to open a restaurant in a prime location of New York that meets people expectations for unique cuisine and quality food and inturn make a profitable business.
#            A Data Scientist was recruited for initial feasibility study to analyse data and submit a report to determine the type of a restaurant to invest in.

# %% [markdown]
# # Data Acquisition and cleaning:

# %% [markdown]
# ## Data Required:

# %% [markdown]
#   Based upon the requirement, the following data’s are collected for the analysis:
#         1.	Total number of population in New York
#         2.	Demography of the population, age group, ethnicity, etc
#         3.	Number of restaurants
#         4.	Number of restaurants in each cuisine
#         5.	Menus in particular restaurant type
#         6.	Number of restaurants for each 1000 people
#         7.	Percentage of people who go faraway to have their food and people who prefer nearby restaurants
#         8.	Competitors in that location
#         9.	Other venues like park, theatre, tourist spots etc so access of people will be more.
#        10.	Easy access to food markets and many other factors are also considered.

# %% [markdown]
# ## Data cleaning:

# %% [markdown]
# Required data’s are collected or scraped from different sources. Then, the data’s were combined into a single table which makes our work further easier. This table contains lot of missing data’s, duplicates and unwanted data’s which are to be cleaned. The missing data’s are filled by taking mean of that column and the duplicate and unwanted data’s are removed.
#
# Data’s of venue is collected from:
# https://cocl.us/new_york_dataset
#
# population data is collected from:
# https://www1.nyc.gov/site/planning/data-maps/nyc-population/census-2010.page
#
#       Problem with population data, there are many data’s which are not required for my analysis. These data’s are removed and the table is reset with required data.

# %% [markdown]
# Feature Selection:
#                      After cleaning, we explore the New York data to get the information about population, restaurant, other venues etc. Find that there are 8 million people live in New York city and about 26,697 restaurants together in all five boroughs of New York. Then collected number of restaurant in each borough and other neighbourhood. Analysing all the information find Queens is the best place to start a restaurant because there the ratio of restaurant is less to total number of population compare to other boroughs.
#                    Race	                      Population
#
#                  White	                          3,661,800
#                  Black or African American	      2,081,507
#                  Asian	                          1,198,334
#                  Two or More Races	                285,089
#                  American Indian and Alaska Native	 34,487
#                  Native Hawaiian and Other
#                  Pacific Islander	                  4,358

# %% [markdown]
# # Data Analysis:

# %% [markdown]
# ## Exploring Queens:

# %% [markdown]
#
#
#                     Detail study of the borough Queens is done, using geolocator we get the map of the borough Queens. Foursquare database is used to get the url of Queens with which information of “Neighborhood”, “venues”, latitudes, longitudes and also particularly about the restaurants in that borough are gathered. We find that there are 1272 restaurants are there.
#
#
#
# ![Neighborhood.png](attachment:Neighborhood.png)

# %% [markdown]
# ## Relationship between Neighborhood and Restaurants:

# %% [markdown]
#   The first factor,  find the total number of restaurants in each neighbourhood, which gives the clear picture about the neighbourhood with less/more number of restaurant.
#
# ![hist.png](attachment:hist.png)

# %% [markdown]
# The second factor, grouped the restaurants of same cuisine and find the ratio of between the neighbourhood and restaurant. So we can easily figure out which type of cuisine is preferred by the people in that particular area.
#
#
# ![download-2.png](attachment:download-2.png)

# %% [markdown]
#                 The third factor, get the information about the top five restaurant and bottom five restaurant in each neighbourhood. So, we can come to know the people’s choice of cuisine.
#
# Top five restaurant in each neighborhood:
#
#
# ![Screenshot%202019-05-01%20at%202.45.24%20AM.png](attachment:Screenshot%202019-05-01%20at%202.45.24%20AM.png)

# %% [markdown]
#       The fourth factor is menu, which place major role keeping the restaurant in top list. Information about the menus, unique recipe, kids special, of each cuisine is collected. Another factor which plays a key role is price. All these informations are collected and analysed.
#
#
#
# ![download-3.png](attachment:download-3.png)

# %% [markdown]
# ## Relationship with population:

# %% [markdown]
#                               First factor, total number of population and number of restaurant in each neighborhood is evaluated. Then, number of restaurant per 1000 people is calculated. This gives an idea about where to open an reataurant.
#                              Second factor, ethinicity of the people. Number of people in each race and the corresponding number of cuisine is calculated. Number of cuisine per 1000 people of particular race is calculated. This gives the information about choice of cuisine.
#                             Third factor, percentage of people who likes to go near to have their food and the percentage of people who likes to go for nearby restaurant.
#                             Other factor which plays a major role in selecting a location is venues. The neighborhood with more number of venues like theatre, gym, park, museum etc are the places where more number of people will come. So neighborhood with most number of neighborhood is identified.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
#      In this study, I have analysed the relationship between neighborhood and restaurant, type of ciusine, total number of cuisine in each neighborhood, top rated cuisine, menus, eithynicity of population, restaurant per 1000 population, neighborhood with more number of venues. By kclustering we find that neighborhood “Astoria” is a best place to open a restaurant
